# %% [markdown]
# # Estructura Economica Argentina
# ## Analisis de la evolucion del sector de la economia: Cria de Animales

# %%
#IMPORTO PANDAS
import pandas as pd
#IMPORTO NUMPY
import numpy as np
#IMPORTO MATPLOTLIB
import matplotlib.pyplot as plt

# %%
        #'ANIO'   ,'TRIMESTRE', 'VAB_K_CRIA_ANIMALES', 'VAB_K_TOTAL')
VAB   = [[2004    , 1         , 6804               , 390787],
         [2004    , 2         , 4015               , 439743],
         [2004    , 3         , 16634              , 406578],
         [2004    , 4         , 14657              , 412601],
         [2005    , 1         , 8281               , 419641],
         [2005    , 2         , 702                , 498534],
         [2005    , 3         , 15627              , 437277],
         [2005    , 4         , 12869              , 445761],
         [2006    , 1         , 8255               , 451524],
         [2006    , 2         , 5293               , 525867],
         [2006    , 3         , 17122              , 477872],
         [2006    , 4         , 13089              , 482693],
         [2007    , 1         , 8304               , 485615],
         [2007    , 2         , 5099               , 575227],
         [2007    , 3         , 16492              , 510805],
         [2007    , 4         , 13414              , 521609],
         [2008    , 1         , 7726               , 513983],
         [2008    , 2         , 4926               , 603851],
         [2008    , 3         , 17518              , 539985],
         [2008    , 4         , 13132              , 513459],
         [2009    , 1         , 843                , 483000],
         [2009    , 2         , 4987               , 532732],
         [2009    , 3         , 16553              , 512817],
         [2009    , 4         , 12649              , 518187],
         [2010    , 1         , 7813               , 513703],
         [2010    , 2         , 4805               , 621308],
         [2010    , 3         , 14718              , 557180],
         [2010    , 4         , 11526              , 559799],
         [2011    , 1         , 8185               , 552173],
         [2011    , 2         , 502                , 646899],
         [2011    , 3         , 1474               , 590445],
         [2011    , 4         , 11619              , 584565],
         [2012    , 1         , 8115               , 558391], 
         [2012    , 2         , 4602               , 614896],
         [2012    , 3         , 16093              , 582963],
         [2012    , 4         , 12326              , 584095],
         [2013    , 1         , 8292               , 558890],
         [2013    , 2         , 4825               , 650953],
         [2013    , 3         , 15833              , 595017],
         [2013    , 4         , 1225               , 587118],
         [2014    , 1         , 8222               , 554540],
         [2014    , 2         , 4452               , 642098], 
         [2014    , 3         , 15094              , 576457],
         [2014    , 4         , 11636              , 575375],
         [2015    , 1         , 8232               , 558293],
         [2015    , 2         , 4749               , 669072],
         [2015    , 3         , 14431              , 597180],
         [2015    , 4         , 11151              , 587215], 
         [2016    , 1         , 791                , 560466], 
         [2016    , 2         , 3881               , 644708],
         [2016    , 3         , 13618              , 578023],
         [2016    , 4         , 10301              , 580882],
         [2017    , 1         , 7841               , 564388],
         [2017    , 2         , 4024               , 664320],
         [2017    , 3         , 14246              , 597453],
         [2017    , 4         , 10409              , 599985],
         [2018    , 1         , 8196               , 583597],
         [2018    , 2         , 4138               , 632428]]

# %%
#LO CONVIERTO EN UN DATAFRAME AGREGANDOLE LOS NOMBRES DE LAS COLUMNAS
VAB = pd.DataFrame(data=VAB, columns=['anio', 'trimestre','VAB_CRIA_ANIMALES','VAB_TOTAL'])

# %%
VAB = VAB.set_index(['anio','trimestre'])

# %% [markdown]
# ## Valor Agregado a Precios Constantes

# %% [markdown]
# ### Cria de Animales

# %% [markdown]
# #### De 2004 a 2018, trimestre por trimestre

# %%
ax = plt.gca()
VAB[['VAB_CRIA_ANIMALES']].plot(ax=ax, kind='bar', title ="Valor Agregado Bruto a Precios Constantes", figsize=(15, 5), legend=True, fontsize=12);

# %%
ax = plt.gca()
VAB[['VAB_CRIA_ANIMALES']].plot(ax=ax, kind='area', title ="Valor Agregado Bruto a Precios Constantes", figsize=(15, 5), legend=True, fontsize=12);

# %%
VAB_total = VAB.reset_index()
VAB_NEW = pd.DataFrame(columns=['anio', 'VAB_CRIA_ANIMALES', 'VAB_TOTAL'])
VAB_NEW.set_index('anio')
VAB_NEW.loc[0] = ['2004', VAB_total[VAB_total['anio'] == 2004]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2004]['VAB_TOTAL'].sum()]
VAB_NEW.loc[1] = ['2005', VAB_total[VAB_total['anio'] == 2005]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2005]['VAB_TOTAL'].sum()]
VAB_NEW.loc[2] = ['2006', VAB_total[VAB_total['anio'] == 2006]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2006]['VAB_TOTAL'].sum()]
VAB_NEW.loc[3] = ['2007', VAB_total[VAB_total['anio'] == 2007]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2007]['VAB_TOTAL'].sum()]
VAB_NEW.loc[4] = ['2008', VAB_total[VAB_total['anio'] == 2008]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2008]['VAB_TOTAL'].sum()]
VAB_NEW.loc[5] = ['2009', VAB_total[VAB_total['anio'] == 2009]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2009]['VAB_TOTAL'].sum()]
VAB_NEW.loc[6] = ['2010', VAB_total[VAB_total['anio'] == 2010]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2010]['VAB_TOTAL'].sum()]
VAB_NEW.loc[7] = ['2011', VAB_total[VAB_total['anio'] == 2011]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2011]['VAB_TOTAL'].sum()]
VAB_NEW.loc[8] = ['2012', VAB_total[VAB_total['anio'] == 2012]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2012]['VAB_TOTAL'].sum()]
VAB_NEW.loc[9] = ['2013', VAB_total[VAB_total['anio'] == 2013]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2013]['VAB_TOTAL'].sum()]
VAB_NEW.loc[10] = ['2014', VAB_total[VAB_total['anio'] == 2014]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2014]['VAB_TOTAL'].sum()]
VAB_NEW.loc[11] = ['2015', VAB_total[VAB_total['anio'] == 2015]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2015]['VAB_TOTAL'].sum()]
VAB_NEW.loc[12] = ['2016', VAB_total[VAB_total['anio'] == 2016]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2016]['VAB_TOTAL'].sum()]
VAB_NEW.loc[13] = ['2017', VAB_total[VAB_total['anio'] == 2017]['VAB_CRIA_ANIMALES'].sum(), VAB_total[VAB_total['anio'] == 2017]['VAB_TOTAL'].sum()]
VAB_NEW = VAB_NEW.set_index('anio')
VAB_NEW
# Out:
#      VAB_CRIA_ANIMALES VAB_TOTAL
# anio
# 2004             42110   1649709
# 2005             37479   1801213
# 2006             43759   1937956
# 2007             43309   2093256
# 2008             43302   2171278
# 2009             35032   2046736
# 2010             38862   2251990
# 2011             21780   2374082
# 2012             41136   2340345
# 2013             30175   2391978
# 2014             39404   2348470
# 2015             38563   2411760
# 2016             28591   2364079
# 2017             36520   2426146

# %% [markdown]
# ### Ahora lo mismo, pero por anio.

# %%
ax = plt.gca()
VAB_NEW[['VAB_CRIA_ANIMALES']].plot(ax=ax, kind='bar', title ="Valor Agregado Bruto a Precios Constantes", figsize=(15, 5), legend=True, fontsize=12);

# %%
ax = plt.gca()
VAB_NEW[['VAB_CRIA_ANIMALES']].plot(ax=ax, kind='area', title ="Valor Agregado Bruto a Precios Constantes", figsize=(15, 5), legend=True, fontsize=12);

# %% [markdown]
# ### Lo comparamos con el VAB total, es decir de todos los sectores

# %%
ax = plt.gca()
ax.set_ylabel('VAB Cria Animales')
casos.VAB_CRIA_ANIMALES.plot(ax=ax,kind='area', figsize=(15, 5))
casos.VAB_TOTAL.plot(ax=ax, secondary_y=True, style='r')
ax.right_ax.set_ylabel('VAB TOTAL');

# %% [markdown]
# #### Vemos como el VAB Total tiene una tendencia creciente a lo largo del tiempo, sin embargo el VAB de Cria de Animales no parece evolucionar con esta tendencia. A decir verdad este ultimo no presenta ni tendencia bajista o alcista de largo plazo, sino mas bien un estado de oscilamiento continuo.

# %% [markdown]
# # Indices de Precios Implicitos (IPI)

# %%
#CARGAR LOS DATOS EN EL MISMO DATAFRAME QUE SIEMPRE
